# %%
from pyndamics import Simulation
from pyndamics.emcee import *

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",.1,plot=True)
sim.params(a=1,K=10)
sim.run(0,10)

# %%
model=MCMCModel(sim,a=Uniform(.001,5),K=Uniform(6,20),initial_h=Normal(4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-42f08cee3cd0> in <module>()
# ----> 1 model=MCMCModel(sim,a=Uniform(.001,5),K=Uniform(6,20),initial_h=Normal(4))
#
# /Users/bblais/anaconda/lib/python2.7/site-packages/pyndamics/emcee/pemcee.pyc in __init__(self, sim, **kwargs)
#     215                     _c=sim.get_component(name)
#     216                 except IndexError:
# --> 217                     raise ValueError,"%s is a bad initial variable becayse %s is not a variable in the dynamical model." % (key,name)
#     218                 self.initial_components[key]=_c
#     219
#
# ValueError: initial_h is a bad initial variable becayse h is not a variable in the dynamical model.
